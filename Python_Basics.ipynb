# %% [markdown]
# <a href="https://colab.research.google.com/github/AshishNalawade0188/CDAC/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#2
print("Hello World!")
# Out:
# Hello World!

# %%
#3
name = input("Enter your Name : ")
print(name)
# Out:
# Enter your Name : Ashsih
# Ashsih

# %%
#4
print("Hello World!")
# Out:
# Hello World!

# %%
#5
name = input("Enter your Name : ")
print(name)
# Out:
# Enter your Name : kunal
# kunal

# %%
#6
a=5
b=10

a,b=b,a

print(a)
print(b)
# Out:
# 10
# 5

# %%
#7
a = 5
b = 2

print("Addition :", a+b)
print("subtraction :", a-b)
print("Multiplication :", a*b)
print("Division :", a/b)
print("Power  :", a**b)
print("Floor Division :", a//b)
print("Modulus :", a%b)
# Out:
# Addition : 7
# subtraction : 3
# Multiplication : 10
# Division : 2.5
# Power  : 25
# Floor Division : 2
# Modulus : 1

# %%
#8
r = int(input("give the radius : "))
pi = 3.14

area = pi*r**2
print('Area of circle : ',area)

circumference = 2*pi*r
print('Circumference of Circle : ',circumference)
# Out:
# give the radius : 12
# Area of circle :  452.16
# Circumference of Circle :  75.36

# %%
#9)
length = int(input("give the length : "))
breadth = int(input("give the breadth : "))

Area = length*breadth
print('Area of rectangle : ',Area)

perimeter = 2*(length+breadth)
print("Perimeter of rectangle :",perimeter)
# Out:
# give the length : 10
# give the breadth : 10
# Area of rectangle :  100
# Perimeter of rectangle : 40

# %%
#10
name = input("Enter your name : ")
age = int(input("Enter your age : "))
address = input("Enter your address : ")
mobile = int(input("Enter your mobile number : "))

print(name,age,address,mobile, sep="-")
# Out:
# Enter your name : Ashish
# Enter your age : 25
# Enter your address : dholwad
# Enter your mobile number : 456133789
# Ashish-25-dholwad-456133789

# %%
a = 5
b = 10
c = 15
a, b, c = b, c, a
print(a, b, c)
# Out:
# 10 15 5
